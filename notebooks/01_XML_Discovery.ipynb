# %%
import xml.etree.ElementTree as ET
from pathlib import Path
from music_library_tools.plist import plist_to_dict

# %%
xml_path = "/Users/stephenusher/Documents/Steve's Folder/music-library-tools/exports/raw/"
xml_file = xml_path + "MusicLibrary_2026_08_03.xml"

# %%
tree = ET.parse(xml_file)
root = tree.getroot()

# %%
type(root)
# Out:
# xml.etree.ElementTree.Element

# %%
root.tag
# Out:
# 'plist'

# %%
len(root)
# Out:
# 1

# %%
for i, child in enumerate(root):
    print(f"Child {i}")
    print(f"Tag: {child.tag}")
    print(f"Children: {len(child)}")
# Out:
# Child 0
# Tag: dict
# Children: 20

# %%
library = root[0]

for i in range(0, len(library), 2):
    key = library[i]
    value = library[i + 1]
    
    print(f"{i // 2 + 1:2}. {key.text:20} -> {value.tag}")
# Out:
#  1. Major Version        -> integer
#  2. Minor Version        -> integer
#  3. Date                 -> date
#  4. Application Version  -> string
#  5. Features             -> integer
#  6. Show Content Ratings -> true
#  7. Music Folder         -> string
#  8. Library Persistent ID -> string
#  9. Tracks               -> dict
# 10. Playlists            -> array

# %%
tracks = None

for i in range(0, len(library), 2):
    if library[i].text == "Tracks":
        tracks = library[i + 1]
        break

# %%
type(tracks)
# Out:
# xml.etree.ElementTree.Element

# %%
tracks.tag
# Out:
# 'dict'

# %%
len(tracks)
# Out:
# 38060

# %%
first_track_key = tracks[0]
first_track = tracks[1]

print(first_track_key.text)
print(first_track.tag)
print(len(first_track))
# Out:
# 1704
# dict
# 68

# %%
for i in range(0, 10, 2):
    key = first_track[i]
    value = first_track[i + 1]
    
    print(key.text)
    print(value.tag)
    print(value.text)
    print("-" * 40)
# Out:
# Track ID
# integer
# 1704
# ----------------------------------------
# Name
# string
# Hells Bells
# ----------------------------------------
# Artist
# string
# AC/DC
# ----------------------------------------
# Album
# string
# Back In Black
# ----------------------------------------
# Genre
# string
# Rock
# ----------------------------------------

# %%
from music_library_tools.plist import plist_to_dict

# %%
track = plist_to_dict(first_track)
# Out:
# Function has been called

# %%
track
# Out:
# {'Name': 'Hells Bells',
#  'Artist': 'AC/DC',
#  'Album': 'Back In Black',
#  'Genre': 'Rock',
#  'Kind': 'Purchased AAC audio file',
#  'Comments': 'Owner: Steve',
#  'Sort Album': 'AC/DC - 1980',
#  'Persistent ID': 'EA6442D8ED513382',
#  'Track Type': 'File',
#  'Location': 'file:///Volumes/Steve/Music/iTunes/Music/AC_DC/Back%20In%20Black/01%20Hells%20Bells.m4a'}
